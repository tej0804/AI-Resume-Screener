# %%
# !pip install requests beautifulsoup4 pandas lxml
# Out:
# Requirement already satisfied: requests in c:\users\tulsiram\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (2.31.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\tulsiram\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (4.14.3)
# Requirement already satisfied: pandas in c:\users\tulsiram\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (2.3.1)
# Requirement already satisfied: lxml in c:\users\tulsiram\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (6.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tulsiram\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tulsiram\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tulsiram\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tulsiram\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests) (2023.5.7)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\tulsiram\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from beautifulsoup4) (2.8.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\tulsiram\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from beautifulsoup4) (4.14.1)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\tulsiram\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tulsiram\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tulsiram\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tulsiram\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\tulsiram\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import requests  #fetch webpages
from bs4 import BeautifulSoup #extract content from http
import pandas as pd
import time #pause btw requests
import random # randomize delay

# %%
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0 Safari/537.36"
}

# %%
SEARCH_ROLES = {
    "data_scientist": "data-scientist",
    "machine_learning_engineer": "machine-learning-engineer",
    "data_analyst": "data-analyst",
    "python_developer": "python-developer"
}

BASE_URL = "https://internshala.com/jobs/{role}-jobs/"

# %%
def get_job_links(role_url, max_links=10):
    response = requests.get(role_url, headers=HEADERS)
    soup = BeautifulSoup(response.text, "html.parser")

    links = []

    for a in soup.find_all("a", href=True):
        href = a.get("href")
        if href.startswith("/job/detail/"):
            links.append("https://internshala.com" + href)

    return list(dict.fromkeys(links))[:max_links]

# %%
test_role = SEARCH_ROLES["data_scientist"]
test_url = BASE_URL.format(role=test_role)

print("Testing URL:", test_url)

test_links = get_job_links(test_url, max_links=5)

print("Job links found:")
for link in test_links:
    print(link)
# Out:
# Testing URL: https://internshala.com/jobs/data-scientist-jobs/
# Job links found:
# https://internshala.com/job/detail/data-scientist-job-in-mumbai-at-dhurin1767519139
# https://internshala.com/job/detail/data-scientist-job-in-ahmedabad-at-growexx1767177208
# https://internshala.com/job/detail/data-scientist-job-in-haryana-at-namshicom1767521410
# https://internshala.com/job/detail/remote-data-scientist-job-at-credgenics1767868989
# https://internshala.com/job/detail/data-scientist-job-in-maharashtra-at-arkray-inc1767958147

# %%
test_links = get_job_links(
    BASE_URL.format(role=SEARCH_ROLES["data_scientist"]),
    max_links=5
)

print("Links found:", len(test_links))
for l in test_links:
    print(l)
# Out:
# Links found: 5
# https://internshala.com/job/detail/data-scientist-job-in-mumbai-at-dhurin1767519139
# https://internshala.com/job/detail/data-scientist-job-in-ahmedabad-at-growexx1767177208
# https://internshala.com/job/detail/data-scientist-job-in-haryana-at-namshicom1767521410
# https://internshala.com/job/detail/remote-data-scientist-job-at-credgenics1767868989
# https://internshala.com/job/detail/data-scientist-job-in-maharashtra-at-arkray-inc1767958147

# %% [markdown]
# ## Job scraping

# %%
def scrape_job_page(job_url):
    response = requests.get(job_url, headers=HEADERS)
    soup = BeautifulSoup(response.text, "html.parser")

    # job title
    title_tag = soup.find("h1")
    job_title = title_tag.get_text(strip=True) if title_tag else ""

    # company
    company_tag = soup.find("div", class_="company_name")
    company = company_tag.get_text(strip=True) if company_tag else ""

    # location
    location_tag = soup.find("span", class_="location_link")
    location = location_tag.get_text(strip=True) if location_tag else ""

    # job description (ROBUST)
    desc_container = soup.find("div", class_="internship_details")
    if desc_container:
        job_description = desc_container.get_text(separator=" ", strip=True)
    else:
        job_description = ""

    return {
        "job_title": job_title,
        "company": company,
        "location": location,
        "job_description": job_description
    }

# %%
# DEBUG: inspect one job page fully
test_link = get_job_links(
    BASE_URL.format(role=SEARCH_ROLES["data_scientist"]),
    max_links=1
)[0]

job_data = scrape_job_page(test_link)

print("Keys:", job_data.keys())
for k, v in job_data.items():
    print(f"\n{k}:\n{v[:1000]}")
# Out:
# Keys: dict_keys(['job_title', 'company', 'location', 'job_description'])
#
# job_title:
# Data Scientist
#
# company:
# Dhurin
#
# location:
#
#
# job_description:
# About the job About the Company Dhurin is a fast-growing data science firm serving financial services industry. We work with banks, NBFCs, fintech and other financial institutions. Our work is in the space of risk, fraud, collections, marketing, sales, and operations through it we directly influence how financial institutions make smarter decisions. Dhurin is the place for someone who is passionate about data and wants to grow with a well-positioned firm. Role Overview We are looking for Data Scientists (AI/ML Developers) across levels to join our Mumbai team. The role focuses on credit and fraud risk analytics within the retail banking space. You will design, develop, and implement ML models that drive smarter decision-making for financial institutions. Responsibilities & Requirements 2 to 10 years of AI/ML/ Data Science experience with exposure to Credit or Fraud risk in Retail banking/financial services Skills: Python and SQL Strong track record of building and deploying ML/statisti

# %%
jobs = []

for role_name, role_slug in SEARCH_ROLES.items():
    search_url = BASE_URL.format(role=role_slug)
    print(f"\nScraping role: {role_name}")

    job_links = get_job_links(search_url, max_links=10)
    print(f"Found {len(job_links)} links")

    for link in job_links:
        print("  Scraping:", link)
        job_data = scrape_job_page(link)

        # Quality filter: ensure meaningful JD
        if len(job_data["job_description"]) > 300:
            jobs.append(job_data)

        time.sleep(random.uniform(1.5, 3))
# Out:
# Scraping role: data_scientist
# Found 10 links
#   Scraping: https://internshala.com/job/detail/data-scientist-job-in-mumbai-at-dhurin1767519139
#   Scraping: https://internshala.com/job/detail/data-scientist-job-in-ahmedabad-at-growexx1767177208
#   Scraping: https://internshala.com/job/detail/data-scientist-job-in-haryana-at-namshicom1767521410
#   Scraping: https://internshala.com/job/detail/remote-data-scientist-job-at-credgenics1767868989
#   Scraping: https://internshala.com/job/detail/data-scientist-job-in-maharashtra-at-arkray-inc1767958147
#   Scraping: https://internshala.com/job/detail/fresher-remote-data-scientist-job-at-v4cai1767783488
#   Scraping: https://internshala.com/job/detail/remote-data-scientist-job-at-mindsprint1767871987
#   Scraping: https://internshala.com/job/detail/remote-data-scientist-job-at-digital-ipsum1765446548
#   Scraping: https://internshala.com/job/detail/fresher-remote-data-scientist-job-at-lendinghelio1764741581
#   Scraping: https://internshala.com/job/detail/fresher-remote-data-scientist-job-at-deepthought-culturetech-ventures-private-limited1767673426
#
# Scraping role: machine_learning_engineer
# Found 10 links
#   Scraping: https://internshala.com/job/detail/machine-learning-engineer-job-in-bangalore-at-ab-inbev-gcc-india1767350347
#   Scraping: https://internshala.com/job/detail/remote-machine-learning-engineer-job-at-tricog-health1767874389
#   Scraping: https://internshala.com/job/detail/machine-learning-engineer-job-in-chennai-at-optisol-business-solutions1767778876
#   Scraping: https://internshala.com/job/detail/customer-acquisition-associate-job-in-delhi-at-wwf-india1766218176
#   Scraping: https://internshala.com/job/detail/administration-trainee-job-in-chennai-at-sevalaya1765872115
#   Scraping: https://internshala.com/job/detail/rpa-automation-analyst-job-in-mumbai-at-alfalabs-technologies1765443618
#   Scraping: https://internshala.com/job/detail/administration-trainee-job-in-goa-velha-at-antarang-foundation1765449591
#   Scraping: https://internshala.com/job/detail/junior-game-designer-job-in-gurgaon-at-adstacks-media1765514562
#   Scraping: https://internshala.com/job/detail/secretary-job-in-mumbai-at-the-yoga-institute1765955785
#   Scraping: https://internshala.com/job/detail/fresher-remote-ai-first-digital-marketer-job-at-u-i1766055436
#
# Scraping role: data_analyst
# Found 10 links
#   Scraping: https://internshala.com/job/detail/remote-data-analyst-job-at-eccentric1767868388
#   Scraping: https://internshala.com/job/detail/remote-data-analyst-job-at-saras-analytics1767871086
#   Scraping: https://internshala.com/job/detail/fresher-remote-data-analyst-job-at-statusneo1767783547
#   Scraping: https://internshala.com/job/detail/remote-data-analyst-job-at-infinit-o1767873435
#   Scraping: https://internshala.com/job/detail/fresher-data-analyst-job-in-haryana-at-easemytripcom1767177074
#   Scraping: https://internshala.com/job/detail/fresher-data-analyst-job-in-multiple-locations-at-raghav-anand1766397143
#   Scraping: https://internshala.com/job/detail/remote-data-analyst-job-at-water-town-swim-school1767933686
#   Scraping: https://internshala.com/job/detail/fresher-remote-part-time-data-analyst-job-at-peroptyx1767006400
#   Scraping: https://internshala.com/job/detail/remote-data-analyst-job-at-ai-certs1767762259
#   Scraping: https://internshala.com/job/detail/remote-data-analyst-job-at-digital-ipsum1765446478
#
# Scraping role: python_developer
# Found 9 links
#   Scraping: https://internshala.com/job/detail/python-developer-job-in-haryana-at-binary-semantics-limited1767181749
#   Scraping: https://internshala.com/job/detail/python-developer-job-in-maharashtra-at-mafatlal-technologies1767954851
#   Scraping: https://internshala.com/job/detail/python-developer-job-in-maharashtra-at-mindstix-software-labs1767781987
#   Scraping: https://internshala.com/job/detail/python-developer-job-in-coimbatore-at-ultrafly-solutions-private-limited1767918609
#   Scraping: https://internshala.com/job/detail/python-developer-job-in-haryana-at-cloudhire1767959047
#   Scraping: https://internshala.com/job/detail/python-developer-job-in-bangalore-at-appsforbharat1767699547
#   Scraping: https://internshala.com/job/detail/fresher-remote-python-developer-job-at-the-mail-whale1767877210
#   Scraping: https://internshala.com/job/detail/fresher-remote-python-developer-job-at-taiy1765801324
#   Scraping: https://internshala.com/job/detail/fresher-python-developer-job-in-hyderabad-at-intellativ1767100074

# %%
# creating & verifying dataset
df_jobs = pd.DataFrame(jobs)

print("Before cleaning:", df_jobs.shape)

df_jobs.drop_duplicates(subset="job_description", inplace=True)
df_jobs = df_jobs[df_jobs["job_description"].notna()]
df_jobs = df_jobs[df_jobs["job_description"].str.len() > 300]

print("After cleaning:", df_jobs.shape)

df_jobs.head()
# Out:
# Before cleaning: (39, 4)
# After cleaning: (39, 4)
#         job_title       company location  \
# 0  Data Scientist        Dhurin
# 1  Data Scientist       GrowExx
# 2  Data Scientist    Namshi.com
# 3  Data Scientist    Credgenics
# 4  Data Scientist  ARKRAY, Inc.
#
#                                      job_description
# 0  About the job About the Company Dhurin is a fa...
# 1  About the job About the Company Growexx is loo...
# 2  About the job Title: Data Scientist Location: ...
# 3  About the job About Credgenics: Credgenics is ...
# 4  About the job Job title: Data Scientist (Full ...

# %%
print("Total jobs collected:", len(jobs))
# Out:
# Total jobs collected: 39

# %%
jobs[0].keys()
# Out:
# dict_keys(['job_title', 'company', 'location', 'job_description'])

# %%
print(jobs[0]['job_title'])
print(jobs[0]['company'])
print(len(jobs[0]['job_description']))
# Out:
# Data Scientist
# Dhurin
# 2613

# %%
import os

output_dir = "resumes"
os.makedirs(output_dir, exist_ok=True)

output_path = os.path.join(output_dir, "job_descriptions.csv")

df_jobs.to_csv(output_path, index=False, encoding="utf-8")

print("Saved to:", output_path)
# Out:
# Saved to: resumes\job_descriptions.csv

# %%
import os
print(os.path.getsize(output_path))
# Out:
# 138562

# %%
df_test = pd.read_csv(output_path)
df_test.shape
df_test.head(2)
# Out:
#         job_title  company  location  \
# 0  Data Scientist   Dhurin       NaN
# 1  Data Scientist  GrowExx       NaN
#
#                                      job_description
# 0  About the job About the Company Dhurin is a fa...
# 1  About the job About the Company Growexx is loo...
